# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("cleaned_dataset.csv")
df.head()
# Out:
#         Brand  Current Price  Original Price  Discount Percentage  Rating  \
# 0       noise        82990.0         89900.0             7.686318     4.0
# 1  fire-boltt         3799.0         16999.0            77.651627     4.3
# 2        boat         1999.0          7990.0            74.981227     3.8
# 3  fire-boltt         1799.0         19999.0            91.004550     4.3
# 4       noise         1599.0          4999.0            68.013603     4.1
#
#    Number OF Ratings                              Model Name Dial Shape  \
# 0               65.0   Wrb-sw-colorfitpro4alpha-std-rgld_pnk    Missing
# 1            20788.0                                  BSW046    Missing
# 2            21724.0                               Wave Call    Missing
# 3            13244.0                                  BSW053    Missing
# 4            13901.0  Wrb-sw-colorfitpulsegobuzz-std-blk_blk    Missing
#
#   Strap Color Strap Material  Touchscreen  Battery Life (Days)  Bluetooth  \
# 0     Missing        Missing            1                  8.0          1
# 1     Missing        Silicon            1                  3.5          1
# 2     Missing        Silicon            1                  8.0          1
# 3     Missing        Silicon            1                  3.5          1
# 4     Missing          Other            1                  8.0          1
#
#    Display Size     Weight  rating_placeholder_flag  reviews_placeholder_flag  \
# 0           1.5  35 - 50 g                    False                     False
# 1           1.8  50 - 75 g                    False                     False
# 2           1.7  35 - 50 g                    False                     False
# 3           1.8      75g +                    False                     False
# 4           1.7  35 - 50 g                    False                     False
#
#    price_logic_flag
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %%
df.shape
# Out:
# (437, 18)

# %%
df.describe()
# Out:
#        Current Price  Original Price  Discount Percentage      Rating  \
# count     437.000000      437.000000           437.000000  437.000000
# mean    12865.384439    13687.661327            -3.615367    4.034783
# std     17774.451831    14525.752208           167.195443    0.553702
# min      1199.000000     1669.000000         -1650.093762    1.000000
# 25%      2299.000000     5999.000000            14.286395    3.900000
# 50%      3999.000000     7999.000000            46.861519    4.100000
# 75%     17490.000000    14995.000000            64.012803    4.300000
# max    139990.000000    96390.000000            91.004550    5.000000
#
#        Number OF Ratings  Touchscreen  Battery Life (Days)   Bluetooth  \
# count         437.000000   437.000000           437.000000  437.000000
# mean        10002.494279     0.945080            14.278550    0.990847
# std         38321.350425     0.228085             7.449720    0.095343
# min             1.000000     0.000000             0.750000    0.000000
# 25%            99.000000     1.000000             8.000000    1.000000
# 50%           996.000000     1.000000            14.077392    1.000000
# 75%          4694.000000     1.000000            22.000000    1.000000
# max        619130.000000     1.000000            22.000000    1.000000
#
#        Display Size
# count    437.000000
# mean       1.394966
# std        0.503813
# min        0.000000
# 25%        1.300000
# 50%        1.500000
# 75%        1.700000
# max        3.000000

# %%
df.isnull().sum()
# Out:
# Brand                       0
# Current Price               0
# Original Price              0
# Discount Percentage         0
# Rating                      0
# Number OF Ratings           0
# Model Name                  0
# Dial Shape                  0
# Strap Color                 0
# Strap Material              0
# Touchscreen                 0
# Battery Life (Days)         0
# Bluetooth                   0
# Display Size                0
# Weight                      0
# rating_placeholder_flag     0
# reviews_placeholder_flag    0
# price_logic_flag            0
# dtype: int64

# %%
df.sample(5)
# Out:
#           Brand  Current Price  Original Price  Discount Percentage  Rating  \
# 156        boat         2499.0          8990.0            72.202447     4.2
# 104  fire-boltt         3499.0         11999.0            70.839237     4.1
# 352      pebble         4199.0          9499.0            55.795347     4.2
# 219      fitbit        20590.0         21499.0             4.228104     4.1
# 376      pebble         5190.0          7499.0            30.790772     4.1
#
#      Number OF Ratings                                         Model Name  \
# 156             2893.0  Wave Infinity with 1.85" HD Screen, Functional...
# 104            44170.0                                             BSW005
# 352             7828.0  Cosmos luxe 1.36" AMOLED Always-on Display Blu...
# 219             4475.0                                              Versa
# 376              996.0  Venus Bluetooth Calling Smartwatch with Fitnes...
#
#     Dial Shape Strap Color Strap Material  Touchscreen  Battery Life (Days)  \
# 156  Rectangle       Black        Silicon            1            22.000000
# 104    Missing     Missing        Silicon            1             3.500000
# 352     Circle       Green        Silicon            1            22.000000
# 219     Square       Black        Silicon            1             3.500000
# 376     Circle       Black        Silicon            1            14.077392
#
#      Bluetooth  Display Size     Weight  rating_placeholder_flag  \
# 156          1           1.9  20 - 35 g                    False
# 104          1           1.9      75g +                    False
# 352          1           0.1  20 - 35 g                    False
# 219          1           1.3  20 - 35 g                    False
# 376          1           0.0  20 - 35 g                    False
#
#      reviews_placeholder_flag  price_logic_flag
# 156                     False             False
# 104                     False             False
# 352                     False             False
# 219                     False             False
# 376                      True             False

# %%
df["Brand"].value_counts().plot(kind="bar")
plt.title("Brand Distribution")
plt.xlabel("Brand")
plt.ylabel("Count")
plt.show()

# %%
Categoriacal_columns=df.select_dtypes(include=["object","bool"])
numerical_columns=df.select_dtypes(include=["int","float"])
print("No. of categorical columns: ",len(Categoriacal_columns.columns))
print("No. of numerical columns: ",len(numerical_columns.columns))
# Out:
# No. of categorical columns:  9
# No. of numerical columns:  9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Brand                     437 non-null    object
#  1   Current Price             437 non-null    float64
#  2   Original Price            437 non-null    float64
#  3   Discount Percentage       437 non-null    float64
#  4   Rating                    437 non-null    float64
#  5   Number OF Ratings         437 non-null    float64
#  6   Model Name                437 non-null    object
#  7   Dial Shape                437 non-null    object
#  8   Strap Color               437 non-null    object
#  9   Strap Material            437 non-null    object
#  10  Touchscreen               437 non-null    int64
#  11  Battery Life (Days)       437 non-null    float64
#  12  Bluetooth                 437 non-null    int64
#  13  Display Size              437 non-null    float64
#  14  Weight                    437 non-null    object
#  15  rating_placeholder_flag   437 non-null    bool
#  16  reviews_placeholder_flag  437 non-null    bool
#  17  price_logic_flag          437 non-null    bool
# dtypes: bool(3), float64(7), int64(2), object(6)
# memory usage: 52.6+ KB

# %% [markdown]
# # Rating:

# %%
plt.Figure(figsize=(8,6))
sns.histplot(df["Rating"], bins=20, kde=True)
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %% [markdown]
# # Current Price:

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Current Price"], bins=30, kde=True)

plt.title("Distribution of Current Price")
plt.xlabel("Current Price (₹)")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# Observation 1:
#
# - The distribution of Current Price is highly right-skewed, indicating that most smartwatches belong to the budget segment, while only a few products are priced in the premium range.
#
# Observation 2:
#
# - The high standard deviation confirms that prices vary considerably across products, reflecting the presence of both low-cost and high-end smartwatches.
#
# Observation 3:
#
# - The right-skewed distribution suggests that the mean price is likely to be higher than the median due to the influence of a few expensive products.

# %%
plt.figure(figsize=(10,2))

sns.boxplot(x=df["Current Price"])

plt.title("Boxplot of Current Price")

plt.show()

# %% [markdown]
# Distribution Analysis:
# - The distribution of Current Price is highly right-skewed.
# - Most smartwatches are priced below ₹20,000.
# - Only a small number of premium smartwatches are available at very high prices.
#
# Boxplot Analysis:
# - The boxplot reveals several high-price outliers.
# - These outliers are located on the higher price side.
# - Based on domain knowledge, these values are likely genuine premium smartwatch prices rather than data entry errors.

# %% [markdown]
# # Insight:
#
# - The dataset primarily consists of budget smartwatches, with a limited number of premium products. The high-price outliers appear to represent real market products and should be verified before considering any treatment.

# %% [markdown]
# # Original Price:

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Original Price"], bins=30, kde=True)

plt.title("Distribution of Original Price")
plt.xlabel("Original Price")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# ## Distribution Analysis (Histogram)
# Observation 1:
#
# - The distribution of Original Price is highly right-skewed, indicating that most smartwatches have lower original prices, while only a few products belong to the premium price segment.
#
# Observation 2:
#
# - The majority of smartwatches have an original price below ₹20,000, suggesting that the dataset primarily consists of budget and mid-range products.
#
# Observation 3:
#
# - A small number of products have exceptionally high original prices, resulting in a long right tail in the distribution.
#
# Observation 4:
#
# - Since the distribution is right-skewed, the mean original price is expected to be higher than the median, as a few expensive products pull the average upward.

# %%
plt.figure(figsize=(10,2))

sns.boxplot(x=df["Original Price"])

plt.title("Boxplot of Original Price")

plt.show()

# %% [markdown]
# ## Boxplot Analysis
#
# Observation 1:
#
# - The boxplot reveals several high-value outliers in the Original Price feature.
#
# Observation 2:
#
# - These outliers are present only on the higher price side, further confirming the right-skewed nature of the distribution.
#
# Observation 3:
#
# - Based on domain knowledge, these high-price observations appear to represent genuine premium smartwatches rather than data entry errors. Therefore, they should be verified before considering any treatment.

# %% [markdown]
# ## Insight:
#
# - The dataset contains smartwatches from multiple pricing categories, including budget, mid-range, and premium products. However, the majority of products belong to the budget and mid-range segments, while premium smartwatches constitute only a small portion of the dataset.

# %% [markdown]
# # Number of Ratings:

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Number OF Ratings"], bins=30, kde=True)

plt.title("Distribution of Number of Ratings")
plt.xlabel("Number of Ratings")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# ## Histogram Analysis
#
#
# Observation 1:
#
# - The Number of Ratings feature is highly right-skewed and does not follow a normal distribution.
#
# Observation 2:
#
# - Most products have received a relatively small number of customer ratings, while only a few products have accumulated a very large number of reviews.
#
# Observation 3:
#
# - The long right tail indicates the presence of a few highly popular smartwatches.

# %%
plt.figure(figsize=(10,2))

sns.boxplot(x=df["Number OF Ratings"])

plt.title("Boxplot of Number of Ratings")

plt.show()

# %% [markdown]
# ## Boxplot Analysis
#
# Observation 1:
#
# - The boxplot identifies several high-value outliers in the Number of Ratings feature.
#
# Observation 2:
#
# - These outliers most likely represent highly popular products rather than data entry errors.

# %% [markdown]
# ## Insight:
#
# - The dataset contains a small number of highly popular smartwatches with exceptionally large numbers of customer ratings, whereas the majority of products have comparatively fewer reviews.
